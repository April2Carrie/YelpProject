# %%
import pandas as pd
import numpy as np
import csv

# %%
review = pd.read_csv("review_chinsese_philadelphia.csv")
business = pd.read_csv("business_chinese_philadelphia.csv")
review
# Out:
#        Unnamed: 0               review_id                 user_id  \
# 0               1  L0E_Ld__jIATsQ1vA7ZGZw  Cvi8nZTwDVaQkqmmgQwQMw
# 1               2  Vou3XAgjYJBuCO_-h1OQaA  M-00xuAOYLeaGEhPmmKjfg
# 2               3  hozoa1DsTCjpz4UC8YGsNw  ndgHYecgAWEqtjnjE7LtfA
# 3               4  tfucaiy6lG5UbvbmTD4STg  wABHp4fGUC-0acRKhmQO2A
# 4               5  bu0BUkenT8c8nnyKUaF0-A  qmpRRF4HAKuGJEujoK-IdQ
# ...           ...                     ...                     ...
# 56942       56943  fb_xKUoJb-A2wWTSmFndfg  pGmbV55YLG54t8r1W4F3xg
# 56943       56944  4yFZtkdc7SPueWozB6zmwQ  ttg9bK1FuUDZQNIleuR-KQ
# 56944       56945  d_POWSXOV2S7QSO6SOfCNg  I2owOyPHlcXYfhXr8hvodw
# 56945       56946  UKSW7aMzc32KQC_eNwRazg  iTA7VqmHkEX3sUtJLpxHdw
# 56946       56947  MVg4YUQeEhCA7Z7RsBJSVg  7-7A0Avj47slLGV7yBFc8w
#
#                   business_id  stars  useful  funny  cool  \
# 0      D4DZztR7vkbiED6txGUYFg      4       0      0     1
# ...

# %%
business_need = business[['business_id','name','address','review_count','hours','is_open']]

# %%
merged_data = pd.merge(review, business_need, on=["business_id"], how = 'left')
final_data = merged_data[merged_data['is_open'] ==1]
final_data
# Out:
#        Unnamed: 0               review_id                 user_id  \
# 1               2  Vou3XAgjYJBuCO_-h1OQaA  M-00xuAOYLeaGEhPmmKjfg
# 2               3  hozoa1DsTCjpz4UC8YGsNw  ndgHYecgAWEqtjnjE7LtfA
# 3               4  tfucaiy6lG5UbvbmTD4STg  wABHp4fGUC-0acRKhmQO2A
# 4               5  bu0BUkenT8c8nnyKUaF0-A  qmpRRF4HAKuGJEujoK-IdQ
# 5               6  KEY5K6jrl18LLtyZ8bfDxg  _2kdAzmaR6KrWzjBMLoiog
# ...           ...                     ...                     ...
# 56942       56943  fb_xKUoJb-A2wWTSmFndfg  pGmbV55YLG54t8r1W4F3xg
# 56943       56944  4yFZtkdc7SPueWozB6zmwQ  ttg9bK1FuUDZQNIleuR-KQ
# 56944       56945  d_POWSXOV2S7QSO6SOfCNg  I2owOyPHlcXYfhXr8hvodw
# 56945       56946  UKSW7aMzc32KQC_eNwRazg  iTA7VqmHkEX3sUtJLpxHdw
# 56946       56947  MVg4YUQeEhCA7Z7RsBJSVg  7-7A0Avj47slLGV7yBFc8w
#
#                   business_id  stars  useful  funny  cool  \
# 1      eaDZlSuVS0EY67Ke6pRP6Q      5       0      0     0
# ...

# %%
final_data.to_csv('review_final.csv')
